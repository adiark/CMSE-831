# %% [markdown]
# ____
#
# # HW: Review and PCA

# %% [markdown]
# _____
#
# ## Problem #1: (20 pts)
#
# For each of the questions below, open a markdown cell and give your answer. Show your work using $\LaTeX$.
#
# There are certain matrices that occur commonly and it is good to know how they operate on other matrices. For each of the matrices listed here, open a cell and describe what it does when you multiply a matrix by it. That, given some arbitrary $B$, what is $AB$? I made this $2\times 2$ so that it is easy to see the result.
#
# In addition to showing the math, look at what you obtained and interpret the operation.
#
# * $A = \begin{bmatrix} 0 & 1 \\ 1 & 0\end{bmatrix} $
#
# * $A = \begin{bmatrix} \sigma_1 & 0 \\ 0 & \sigma_2 \end{bmatrix} $
#
# * $A = \begin{bmatrix} \sigma_1 & 0 \\ 0 & 0 \end{bmatrix} $
#
# * $A = B^T $
#
# * $A = \begin{bmatrix} \cos(\theta) & -\sin(\theta) \\ \sin(\theta) & \cos(\theta) \end{bmatrix} $
#
# * $A = B^T \begin{bmatrix} \sigma_1 & 0 \\ 0 & \sigma_2 \end{bmatrix} $
#
# * $A = B^{-1}$
#
# * $A =  \begin{bmatrix} 1 & 1 \\ 1 & 1 \end{bmatrix}$
#
# * $A =  \begin{bmatrix} 0 & 1 \\ 0 & 0 \end{bmatrix}$
#
# * $A =  \begin{bmatrix} 0 & 0 \\ 1 & 0 \end{bmatrix}$
#
# Once you are done, [read this page](https://en.wikipedia.org/wiki/List_of_named_matrices). Can you name some of the matrices above?
#
# ----

# %% [markdown]
# 📝 **Answer 1**
#
# Taking an arbitary matrix B as
# * $B = \begin{bmatrix} 1 & 2 \\ 3 & 4\end{bmatrix} $

# %% [markdown]
# **Case 1**
# * $A = \begin{bmatrix} 0 & 1 \\ 1 & 0\end{bmatrix} $
#
# $AB = \begin{bmatrix} 0\times 1 + 1\times 3 & 0\times 2 + 1\times 4 \\ 1\times 1 + 0\times 3 & 1\times 2 + 0\times 4\end{bmatrix} = \begin{bmatrix} 3 & 4 \\ 1 & 2 \end{bmatrix} $
#
# The operation $AB$ reverses the order of the rows in the matirx $B$, while $BA$ reverses the order of column in matrix $B$. The Matrix $A$ is also called as exchange matrix
#
# -----
#
# **Case 2**
# * $A = \begin{bmatrix} \sigma_1 & 0 \\ 0 & \sigma_2 \end{bmatrix} $
#
# $AB = \begin{bmatrix} \sigma_1\times 1 + 0\times 3 & \sigma_1\times 2 + 0\times 4 \\ 0\times 1 + \sigma_2\times 3 & 0\times 2 + \sigma_2\times 4\end{bmatrix} = \begin{bmatrix} \sigma_1 & 2\sigma_1 \\ 3\sigma_2 & 4\sigma_2 \end{bmatrix} $
#
# The operation $AB$ scales the matrix $B$ with respect to values present in the diagonal matrix $A$. The Matrix $A$ is called as a diagonal matrix used for and if $\sigma_1, \sigma_2$ represents singular values then the matrix $A$ is also called as singular matrix
#
# -----
#
# **Case 3**
# * $A = \begin{bmatrix} \sigma_1 & 0 \\ 0 & 0 \end{bmatrix} $
#
# $AB = \begin{bmatrix} \sigma_1\times 1 + 0\times 3 & \sigma_1\times 2 + 0\times 4 \\ 0\times 1 + 0\times 3 & 0\times 2 + 0\times 4\end{bmatrix} = \begin{bmatrix} \sigma_1 & 2\sigma_1 \\ 0 & 0 \end{bmatrix} $
#
# The operation $AB$ reduces the matrix $B$ with respect to values present in the diagonal matrix $A$, i.e. it isolates a specific row or column of matrix $B$. The Matrix $A$ is called as single-entry matrix.
#
# ----
#
# **Case 4**
# * $A = B^T = \begin{bmatrix} 1 & 3 \\ 2 & 4\end{bmatrix} $
#
# $B^TB = \begin{bmatrix} 1\times 1 + 3\times 3 & 1\times 2 + 3\times 4 \\ 2\times 1 + 4\times 3 & 2\times 2 + 4\times 4\end{bmatrix} = \begin{bmatrix} 10 & 14 \\ 14 & 20 \end{bmatrix} $
#
# The operation $AB$ is simply performing multiplication between a matrix and it transpose.
#
# ----
#
# **Case 5**
# * $A = \begin{bmatrix} \cos(\theta) & -\sin(\theta) \\ \sin(\theta) & \cos(\theta) \end{bmatrix} $
#
# $AB = \begin{bmatrix} \cos(\theta)\times 1 -\sin(\theta)\times 3 & \cos(\theta)\times 2 -\sin(\theta)\times 4 \\ \sin(\theta)\times 1 + \cos(\theta)\times 3 & \sin(\theta)\times 2 + \cos(\theta)\times 4\end{bmatrix} = \begin{bmatrix} \cos(\theta) -3\sin(\theta) & 2(\cos(\theta) - 2\sin(\theta)) \\ \sin(\theta) + 3\cos(\theta) & 2(\sin(\theta) + 2\cos(\theta)) \end{bmatrix} $
#
# The above matrix $A$ is a rotation matrix used to rotate any matrix with an angle Φ. The cos(Φ) rotates with respect to x axis and sin(Φ) rotates w.r.t y axis.
#
# ----
#
# **Case 6**
# * $A = B^T \begin{bmatrix} \sigma_1 & 0 \\ 0 & \sigma_2 \end{bmatrix} = \begin{bmatrix} \sigma_1 & 3\sigma_1 \\ 2\sigma_2 & 4\sigma_2 \end{bmatrix}$
#
# $AB = \begin{bmatrix} \sigma_1\times 1 + 3\sigma_1\times 3 & \sigma_1\times 2 + 3\sigma_1\times 4 \\ 2\sigma_2\times 1 + 4\sigma_2\times 3 & 2\sigma_2\times 2 + 4\sigma_2\times 4\end{bmatrix}$
# $AB = \begin{bmatrix} 10\sigma_1 & 14\sigma_1 \\ 14\sigma_2 & 20\sigma_2 \end{bmatrix} $
#
# The above multiplication is a combination of two multiplications we performed above, one we multiply with transpose of its matrix and other with a diagonal matrix to change the scale of our matrix.
#
# ----
#
# **Case 7**
# * $A = B^{-1} = \begin{bmatrix} -2 & 1 \\ 3/2 & -1/2 \end{bmatrix} $
#
# $AB = \begin{bmatrix} -2\times 1 + 1\times 3 & -2\times 2 + 1\times 4 \\ 3/2\times 1 + -1/2\times 3 & 3/2\times 2 + -1/2\times 4\end{bmatrix} = \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix} $
#
# The above matrix $A$ is inverse of matrix $B$, thus upon multiplication we obtain an identity matrix.
#
# ----
#
# **Case 8**
# * $A =  \begin{bmatrix} 1 & 1 \\ 1 & 1 \end{bmatrix}$
#
# $AB = \begin{bmatrix} 1\times 1 + 1\times 3 & 1\times 2 + 1\times 4 \\ 1\times 1 + 1\times 3 & 1\times 2 + 1\times 4\end{bmatrix} = \begin{bmatrix} 4 & 6 \\ 4 & 6 \end{bmatrix} $
#
# The above matrix $A$ is called as matrix of ones or all-ones matrix. The multiplication of $AB$ results a row wise sum of all rows indexes present in a matrix, while $BA$ will result in column wise sum of all column index values.
#
# ----
#
# **Case 9**
# * $A =  \begin{bmatrix} 0 & 1 \\ 0 & 0 \end{bmatrix}$
#
# $AB = \begin{bmatrix} 0\times 1 + 1\times 3 & 0\times 2 + 1\times 4 \\ 0\times 1 + 0\times 3 & 0\times 2 + 0\times 4\end{bmatrix} = \begin{bmatrix} 3 & 4 \\ 0 & 0 \end{bmatrix} $
#
# The matrix $A$ is called as matrix unit and when multiplied with other matrix, it isolates a row or column of that matrix depending upon the multiplication orientation.
#
# ----
#
# **Case 10**
# * $A =  \begin{bmatrix} 0 & 0 \\ 1 & 0 \end{bmatrix}$
#
# $AB = \begin{bmatrix} 0\times 1 + 0\times 3 & 0\times 2 + 0\times 4 \\ 1\times 1 + 0\times 3 & 1\times 2 + 0\times 4\end{bmatrix} = \begin{bmatrix} 0 & 0 \\ 1 & 2 \end{bmatrix} $
#
# The matrix $A$ is a unit matrix and when multiplied with other matrix $B$ it performs a rotation on the matrix and isolates a row or column of $B$

# %% [markdown]
# _____
#
# ## Problem #2: Direction of $v_1$ (10 pts)
#
# Follow these steps:
# 1. read in the iris dataset
# 2. pull out two columns of lengths/widths and separate by flower type (you will have three arrays or dataframes with two columns)
# 3. plot the data: one column versus the other
# 4. center the data by removing the mean from each column; plot again to ensure the centering did what you hoped it would
# 5. perform an SVD on each
# 6. from the columns of $V$, plot lines that are in the direction of $v_1$ and $v_2$; do these for each flower type
# 7. comment on what you see in your figure
#
# ----

# %%
# Answer 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
iris = sns.load_dataset("iris")
iris_setosa = iris[iris['species'] =='setosa'].drop(['petal_length','petal_width','species'], axis = 1)
iris_versicolor = iris[iris['species'] =='versicolor'].drop(['petal_length','petal_width','species'], axis = 1)
iris_virginica = iris[iris['species'] =='virginica'].drop(['petal_length','petal_width','species'], axis = 1)

fig , ax = plt.subplots(1,3,figsize =(18,5))
ax[0].scatter(iris_setosa.sepal_length,iris_setosa.sepal_width)
ax[0].set_title('Setosa')
ax[1].scatter(iris_versicolor.sepal_length,iris_versicolor.sepal_width)
ax[1].set_title('Versicolor')
ax[2].scatter(iris_virginica.sepal_length,iris_virginica.sepal_width)
ax[2].set_title('Virginica')
# Out:
# Text(0.5, 1.0, 'Virginica')

# %%
# centering data with mean normalization
iris_setosa_m = iris_setosa - iris_setosa.mean(axis=0)
iris_versicolor_m = iris_versicolor - iris_versicolor.mean(axis=0)
iris_virginica_m = iris_virginica - iris_virginica.mean(axis=0)

fig , ax = plt.subplots(1,3,figsize =(18,5))
ax[0].scatter(iris_setosa_m.sepal_length,iris_setosa_m.sepal_width)
ax[0].set_title('Centered Setosa')
ax[1].scatter(iris_versicolor_m.sepal_length,iris_versicolor_m.sepal_width)
ax[1].set_title('Centered Versicolor')
ax[2].scatter(iris_virginica_m.sepal_length,iris_virginica_m.sepal_width)
ax[2].set_title('Centered Virginica')
# Out:
# Text(0.5, 1.0, 'Centered Virginica')

# %%
# performing SVD

U_setosa, Σ_setosa , VT_setosa = np.linalg.svd(iris_setosa_m)
V_setosa = VT_setosa.T
U_versicolor, Σ_versicolor , VT_versicolor = np.linalg.svd(iris_versicolor_m)
V_versicolor = VT_versicolor.T
U_virginica, Σ_virginica , VT_virginica = np.linalg.svd(iris_virginica_m)
V_virginica = VT_virginica.T

x = np.linspace(-2,2)

fig , ax = plt.subplots(1,3,figsize =(18,5))
ax[0].scatter(iris_setosa_m.sepal_length,iris_setosa_m.sepal_width)
ax[0].plot(x, x*V_setosa[1,0]/V_setosa[0,0], label="1st PC")
ax[0].plot(x, x*V_setosa[1,1]/V_setosa[0,1], label="2nd PC")
ax[0].set_title('Centered Setosa')
ax[1].scatter(iris_versicolor_m.sepal_length,iris_versicolor_m.sepal_width)
ax[1].plot(x, x*V_versicolor[1,0]/V_versicolor[0,0], label="1st PC")
ax[1].plot(x, x*V_versicolor[1,1]/V_versicolor[0,1], label="2nd PC")
ax[1].set_title('Centered Versicolor')
ax[2].scatter(iris_virginica_m.sepal_length,iris_virginica_m.sepal_width)
ax[2].plot(x, x*V_virginica[1,0]/V_virginica[0,0], label="1st PC")
ax[2].plot(x, x*V_virginica[1,1]/V_virginica[0,1], label="2nd PC")
ax[2].set_title('Centered Virginica')
ax[0].legend()
ax[1].legend()
ax[2].legend()

# %% [markdown]
# **Answer**:
#
# The figures above shows the direction of the first and second principal components generated from our datasets. We can say from above, the first principal component points the direction of maximum variance present in our data and the second principal component is always perpendicular to first principal component, and shows the direction of second most maximum variance present in the data. The components are always perpendicular to each other and can be visualized in a scaled graph like in Centered Setosa.

# %% [markdown]
# ____
#
# ## Problem #3: Quadratic Form (20 pts)
#
# In this problem you will explore a mathematical object that arises frequently in data science: the quadratic form. For now, let's just assume it is an interesting object and build our intuition; then, we'll put it use!
#
# The quadratic form is written as:
# $${\bf x}^TA{\bf x}.$$
# Here, ${\bf x}$ is a vector of arbitrary length and $A$ a matrix.
#
#
# ___
# First question: if ${\bf x}$ has size $n\times 1$, what shape is $A$? What is the shape of ${\bf x}^T$?
#
# **Answer**: if ${\bf x}$ has size $n\times 1$, then shape of $A$ will be $n\times n$ and shape of ${\bf x}^T$ will ne $1\times n$
# ___
#
# Ok, now let's work in 2D so that we can visualize what we are doing. Write ${\bf x}$ as
# $${\bf x} = \begin{bmatrix} x_1 \\ x_2 \end{bmatrix},$$
# where we think of the elements as axes in a 2D space.
#
# ____
# Second question: Let's assume that $A=I$. What is the quadratic form for this case - mathematical and meaning?
#
# **Answer**: If $A=I$ then the quadratic form becomes ${\bf x}^T{\bf x}$. This gives us the euclidean inner product or the sums of squares of the vectors $x_1$ and $x_2$ and is equal to $x_1^2 + x_2^2$. This means the resulting quadratic form is already aligned. Thus, when we plot the resulting curve we get an ellipse aligned parralel to the original coordinate system.
#
# Suppose you write this as ${\bf x}^T{\bf x} = c$ and plot the resulting curve in the $x_2-x_1$ space: what shape do you get? What role does $c$ play? How is the quadratic form itself connected to a [distance](https://en.wikipedia.org/wiki/Mahalanobis_distance)?
#
# **Answer**: If we write ${\bf x}^T{\bf x} = c$, and plot the resulting curve we will get an ellipse parralel to coordinate system. The value of c represents the square distance of the quadratic form from the origin of the coordinate system. If we subtract mean from the vector and transform our coordinate system, then the distance c is called as squared Mahalanobis distance.
# ___
# Great. Let's make $A$ more general now.
# ___
# Third question: For an arbitrary $A = \begin{bmatrix} a_{11} & a_{12} \\ a_{21} & a_{22} \end{bmatrix}$, write out the quadratic form explicitly.
#
# **Answer**: The quadratic form for an arbitrary A will be $a_{11}x_1^2 + (a_{12} + a_{21})x_1x_2 + a_{22}x_2^2$
#
# Same as the previous question: if you plot the quadratic form in the $x_2-x_1$ space, what geometric shape do you get? What role do the diagonal elements play? What about the off-diagonal elements?
#
# **Answer**: If we plot the above quadratic form, we will get a shape resembling an ellipse with some rotation performed about the axes. The diagonal elements of the matrix $A$ will determine the length of the major and minor axis of the ellipse while the off diagonal elements controls the rotation and reflection of the ellipse about the $x_1$ and $x_2$ axes.
# _____
#
# If you are not familiar with these geometric shapes, [read this](https://www.geometrictools.com/Documentation/InformationAboutEllipses.pdf).
#
# ____
# Fourth question: What if you [diagonalize](https://en.wikipedia.org/wiki/Eigendecomposition_of_a_matrix) $A$? Take the quadratic form and write
# $$A = Q\Lambda Q^T.$$
# (Here, I have assumed that $Q$ is orthogonal so that $Q^{-1} = Q^T$.) Substitute this decomposition of $A$ in the quadratic form and interpret what you get. Hint: you can define a new variable ${\bf y} = Q^T{\bf x}$, which is a rotated ${\bf x}$. What do we know about ${\bf y}$ given that $\Lambda$ is diagonal? What geometrical shape do we get if we plot ${\bf y}^T\Lambda{\bf y} = c$?
#
# **Answer**: When we substitute $A = Q\Lambda Q^T$ we get our quadratic form as ${\bf x}^TQ\Lambda Q^T{\bf x}.$ If we take ${\bf y} = Q^T{\bf x}$, then ${\bf y}^T = {\bf x}^TQ$ as Q is orthogonal.
#
# Hence our quadratic equation becomes ${\bf y}^T\Lambda {\bf y}.$ Given $\Lambda$ is diagonal and ${\bf y}$ is a rotated transformation of ${\bf x}$, we can say that the geometrical shape of the plot  ${\bf y}^T\Lambda{\bf y} = c$ will be an ellipse parralelly aligned with the new coordinate system defined by ${\bf y}$ as the equation follows the quadratic form.
#
# ____
#
# With that math done, let's interpret this. We wish to find outliers using a [multivariate Gaussian (MVG)](https://en.wikipedia.org/wiki/Multivariate_normal_distribution).  We model our data with the MVG and want to find all points outside of some contour - perhaps where the MVG drops to $5\%$ - all points outside of that contour are considered outliers. In a DS setting, these outlier points might trigger human intervention (e.g., to look more carefully at the credit card transaction).
#
# [This picture](https://en.wikipedia.org/wiki/Multivariate_normal_distribution#/media/File:MultivariateNormal.png) might be useful.
#
# Does the quadratic form appear naturally in the MVG?
#
# **Answer**: The quadratic form does appear naturally in the exponential term of the MVG density function. The the matrix $A$ in our quadratic form is equal to $\Sigma^{-1}$, the inverse of covariance matrix of our variables.
#
# \begin{equation}\
# \begin{split}
# \mathcal{N}  (\mu, \Sigma) = \frac{1}{(2\pi)^{(k/2)} |\Sigma|^{1/2}} \exp \left\{- \frac{1}{2} \left(x-\mu\right)^{T} \Sigma^{-1} \left(x-\mu \right)  \right\}
# \end{split}
# \end{equation}
#
# ____
#
# Fifth question: How does the data inform the MVG? What properties of the data do we use to build the MVG? If we plot contours of the MVG, what geometric shape will they make? How is the covariance matrix of the data connected to the matrix $A$ above and what does that tell us about the contours?
#
# [Hint](https://geostatisticslessons.com/lessons/errorellipses). Highly recommended!! _Read very slowly and carefully...._
#
#
# **Answer**: An MVG is a multivariate gaussian whose exponential term is in a quadratic form and is equal to squared of Mahalanobis distance from vector $X$ to its mean vector. An MVG of a bivariate vector whose covariance matrix is diagonal will plot a perfect bell curve in a 3D space. The MVG gives us the multivariate probability distribution of our vectors in a defined coordinate system. To build an MVG we determine an appropriate confidence interval of our data by defining the chi-squared value as per the degree of freedom and alpha. We also calculate the covariance matrix of the random vector $X$ (data). Thus, a shape of the gaussian is determined by the confidence interval and variance - covariance matrix.
#
# In 3D an MVG will plot a bell curve in ideal case where individual variables are not correlated. If, the variables are correlated we will see the bell getting thinner and sharper and the orientation of the shape will depend on the nature of correlation.
#
# In 2D an MVG will plot an hyper-ellipse whose size is determined by the diagonal elements of the covariance matrix and the shape and orientation of the ellipse is determined by the off-diagonal elements of the covariance matrix. Thus we can say that the inverse of covariance matrix in the gaussian distribution is equal to the matrix $A$ in our quadratic form.
#
# ____

# %%
# case 1 when A is an identity matrix
A = np.array([[1,0], [0,1]])

def contour_plot(A,n_points,c,title):
    u = np.linspace(-c, c, n_points)
    x, y = np.meshgrid(u, u)

    X = np.vstack([x.flatten(), y.flatten()])
    X = X - X.mean()
    f_x = np.dot(np.dot(X.T, A), X)
    f_x = np.diag(f_x).reshape(n_points, n_points)
    plt.title(title)
    plt.contour(x, y, f_x)
    plt.show()
    

contour_plot(A,100,1,"Contour Plot")

# %%
from mpl_toolkits.mplot3d import Axes3D 
A = np.array([[1,0], [0,1]])

def surface_plot(A,n_points,c,title):
    u = np.linspace(-c, c, n_points)
    x, y = np.meshgrid(u, u)

    X = np.vstack([x.flatten(), y.flatten()])
    X = X - X.mean()
    f_x = np.dot(np.dot(X.T, A), X) 
    f_x = np.diag(f_x).reshape(n_points, n_points)
    
    fig = plt.figure(figsize=(7,7))
    ax = plt.axes(projection='3d')
    ax.plot_surface(x,y, f_x)
    plt.title(title)
    ax.set_xlabel('X-axis', fontweight ='bold')
    ax.set_ylabel('Y-axis', fontweight ='bold')
    ax.set_zlabel('Z-axis', fontweight ='bold')
    
    plt.show()

surface_plot(A,100,1,"3d projection")

# %%
# case 2 when A is a diagonal matrix
A = np.array([[2,0], [0,8]])
contour_plot(A,100,3,"Contour Plot")

# %%
surface_plot(A,100,3,"3d projection")

# %%
# case 3 when A is an arbitary matrix
A = np.array([[2,-1], [2,5]])
contour_plot(A,50,10,"Contour Plot")

# %%
surface_plot(A,50,10,"3d projection")

# %%
# MVG plots
# for consistent results
np.random.seed(1)

n_samples = 125
n_outliers = 25
n_features = 2

# generate Gaussian data of shape (125, 2)
gen_cov = np.eye(n_features)
gen_cov[0, 0] = 1.
X = np.dot(np.random.randn(n_samples, n_features), gen_cov)
# add some outliers
outliers_cov = np.eye(n_features)
outliers_cov[np.arange(1, n_features), np.arange(1, n_features)] = 4.
X[-n_outliers:] = np.dot(np.random.randn(n_outliers, n_features), outliers_cov)

# %%
my_mean = [X[:,0].mean(),X[:,1].mean()]
my_sigma = [[1,-2],[0,3]]

xlen=100
ylen=100

x_ = np.linspace(-10,10,xlen)
y_ = np.linspace(-10,10,ylen)
xx, yy = np.meshgrid(x_, y_)

def gaussian(x,y,mu,sigma):
  r = np.stack([x,y])
  inv_sigma = np.linalg.inv(sigma)
  a = 1/np.sqrt(2*np.pi)*np.sqrt(np.linalg.det(sigma))*np.exp(-((r-mu).T@inv_sigma@(r-mu))/2)

  return a


z = np.zeros((ylen,xlen))
for i in range(ylen):
  for j in range(xlen):
    z[j,i] = gaussian(x=xx[j,i], y = yy[j,i], mu= my_mean, sigma= my_sigma)

# %%
plt.figure(figsize=(7,7))
# create a contour line at .05.
CS = plt.contour(xx,yy,z,levels=[0.05],cmap='magma_r')
plt.clabel(CS, fontsize=15,colors='black')

plt.contourf(xx,yy,z,cmap="magma_r")
plt.scatter(X[:,0],X[:,1],s=2)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
# Out:
# Text(0, 0.5, 'Feature 2')

# %%
# 3D plot
ax.scatter(X[:,0],X[:,1],s=2)
fig = plt.figure(figsize=(7,7))
ax = plt.axes(projection='3d')
ax.plot_surface(xx, yy, z,cmap='viridis',linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

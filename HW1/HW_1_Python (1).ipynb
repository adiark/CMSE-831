# %% [markdown]
# ____
# # HW #1: Python
# ____
#
# This HW is due at midnight Sunday in D2L. Remember that HWs are not done in groups, but on your own. However, if you need help, you are free to use the internet, other students in the class or the instructors.

# %% [markdown]
# ____
#
# ### Markdown
#
# This HW uses a lot of markdown. Knowing markdown well will make your Jupyter notebook life a lot more fun. And, you can use markdown for many other tasks that have nothing to do with Jupyter notebooks. For example, when I want to do quick editing tasks, I very often use [a markdown editor like this one](https://macdown.uranusjr.com/). (If you use a Windows OS, there are equivalents that you can find in the link below.)
#
# Before you get started on the HW problems below, read these webpages:
# * [Markdown Guide](https://www.markdownguide.org/getting-started/)
# * [Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# 👨🏽‍🏫 You will notice that I am using several features of markdown to write this cell! If you open this markdown cell, you can see all of the commands I used.
#
# As you answer the questions below, use the features of markdown, such as lists, web links and [tables](https://www.tablesgenerator.com/markdown_tables).
#
# 👩🏽‍💻 Once you are done learning markdown well, continue to the HW below. **Important:** problem 11 is much more involved than the others, so you might start with that.
# ____

# %% [markdown]
# ✍🏼 **Problem 1**: Read the syllabus for this class and answer the following two questions. Open a markdown cell below this one to put your answers.
# 1. What is the late policy for this class?
# 2. Describe in your own words the Spartan Code of Honor.

# %% [markdown]
# ✏️  **Answer 1**:
# > 1. Arriving late or leaving early without prior arrangement with the instructor of your session counts as an unexcused absence. Three unexcused absences will result in the reduction of your grade by one step (e.g., from 4.0 to 3.5), with additional absences reducing your grade further at the discretion of the course instructor.
#
# > 2. The Spartan code of Honor is something that should be followed in every domain of life. Grades don't define an individual's character, good values do. Honesty in work and in speech not only upholds values of the highest ethical standards but also inculcates the same traits in others around us. Hence, I will carry these values over my lifespan and continue to build myself and make spartans proud. <span style="color:green">*Go Green!*</span> <span style="color:white">*Go White!*</span>
# ***

# %% [markdown]
# ✍🏼 **Problem 2**: Define these terms in your own words, again in a new markdown cell.
# * cardinal number
# * ordinal number
# * nominal number

# %% [markdown]
# ✏️  **Answer 2**:
# > 1. A cardinal number tells the amount or the size of a set. For example, there are 5 coins on the table, here the number 5 is cardinal as it denotes the total number of coins
# > 2. An ordinal number is more concerned about the order of things in a set. For example, if there are 5 cars on the race track then their position attribute (rank (1,2,3,4,5)) will be an ordinal number
# > 3. However, a nominal number is substituted or used as a name. For example, pin code; or a model number of a car is a nominal number. Mathematical calculations are not performed on nominal numbers.
#     >> **Example** - Out of 5 dogs in a dog race, a dog with jersey number 3 was in 1st position. Here 5 is a cardinal number, 3 is a nominal, and 1 is an ordinal number.
# ***

# %% [markdown]
# ✍🏼 **Problem 3**: Write a paragraph about John W. Tukey. You can use the class sides, but also Wikipedia or any other source. Why is he important to data science? Open a markdown cell below this one to put your discussion.

# %% [markdown]
# ✏️  **Answer 3**:
# > ***[John W. Tukey.](https://en.wikipedia.org/wiki/John_Tukey)*** was an American mathematician and statistician, best known for developing **Fast Fourier Transform Algorithm**. He was born in New Bedford, Massachusetts, and obtained his PhD in mathematics from Princeton University. In his early career, he worked as a statistician for bell labs where he invented the term **\`bit\`**. He also coined the term **\`Software\`** which is widely used in the industry. He also introduced the term **\`box plot\`** in his book *exploratory data analysis*. He is important to data science as he has contributed to statistical practices and articulated the important distinction between *exploratory data analysis* and *confirmatory data analysis*. He also developed techniques for robust analysis, which allowed statisticians to attain credible conclusions from partially flawed data. Tukey’s other statistical contributions include the creation of the Stem-and-Leaf Diagram, and Tukey’s Paired Comparisons, all of which have become standard techniques for approaching data analysis using graphs and plots.
# ***

# %% [markdown]
# ✍🏼 **Problem 4**: Open a markdown cell and give your definition of data science.

# %% [markdown]
# ✏️  **Answer 4**:
# > I believe there are two important skills required for data science.
# > - One is technical/theoretical skill, where we learn about how to program our mathematical equations and statistical rules in the computer to get the desired output in form of modeling or visualization.
# > - The other skill is totally related to observation and personal experiences, how well one observes the data, analyze it by keeping a business perspective in mind, and how well one reacts to calculated insights.
#
# >So in layman's terms gaining information from both structured and unstructured data while keeping business acumen in mind is the aim of data science.
# ***

# %% [markdown]
# ✍🏼 **Problem 5**: In a markdown cell below, write two sentences that use the term 'data' as:
# 1. a plural noun,
# 2. a mass noun.

# %% [markdown]
# ✏️  **Answer 5**:
# > - A plural noun
# >   1. The collected data are unstructured.
# >   2. Data modeling is done using data collected from varied sources.
#
# > - A mass noun
# >   1. Terabytes of data can be stored in human DNA.
# >   2. Every action on the internet is recorded in structured data format.
# ***

# %% [markdown]
# ✍🏼 **Problem 6**: Describe in your own words, in a new markdown cell, what a tuple, a list and an array are in Python. Why do we need all three of these? How are they similar? How are they different? What are the use cases for each?

# %% [markdown]
# ✏️  **Answer 6**:
# > - A tuple, list, and array are all various ordered data types in python.
# > - A tuple is an immutable object while a list and array can be changed.
# > - Also, tuples and lists can store any type of data like numbers, strings, whereas arrays only store a single data type.
# > - Each data type has its own use case when comes to coding, arrays are used for computation-intensive work, while the list is often used in multi-type dataset.
# > - The biggest use case of a tuple is where we do not want data to be changed by any process in the environment.
#
#
# | Feature                 | Tuple | List | Array |
# |-------------------------|-------|------|-------|
# | Mutable                 | &#x2612;    | &#x2611;  | &#x2611;   |
# | Ordered                 | &#x2611;   | &#x2611;  | &#x2611;   |
# | Multi Data Type Storage | &#x2611;   | &#x2611;  | &#x2612;    |
# ***

# %% [markdown]
# ✍🏼 **Problem 7**: In a code cell, write code that creates a tuple of values. Print the contents. Then convert that tuple to a list, and print the list. Finally, convert the list to an array and print that. Give two cases, where this procedure works and does not work.

# %%
import numpy as np
tuple1 = ("M", "N", "p")
print(tuple1)
list1 = list(tuple1)
print(list1)
array1 = np.array(list1)
print(array1)

tuple2 = (1, 2, 3)
print(tuple2)
list2 = list(tuple2)
print(list2)
array2 = np.array(list2)
print(array2)
# Out:
# ('M', 'N', 'p')
# ['M', 'N', 'p']
# ['M' 'N' 'p']
# (1, 2, 3)
# [1, 2, 3]
# [1 2 3]

# %% [markdown]
# ✏️  **Answer 7 a**:
# > 1. In the above code when we make a tuple of either string or integer, the conversion between data types is possible, and the data type remains constant.

# %%
import numpy as np
tuple1 = ("M", list(range(5)), 1)
print(tuple1)
list1 = list(tuple1)
print(list1)
array1 = np.array(list1)
print(array1)

tuple2 = (1, "2", 3)
print(tuple2)
list2 = list(tuple2)
print(list2)
array2 = np.array(list2)
print(array2)
# Out:
# ('M', [0, 1, 2, 3, 4], 1)
# ['M', [0, 1, 2, 3, 4], 1]
# ['M' list([0, 1, 2, 3, 4]) 1]
# (1, '2', 3)
# [1, '2', 3]
# ['1' '2' '3']
# C:\Users\Adi\AppData\Local\Temp\ipykernel_27760\3102286098.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   array1 = np.array(list1)

# %% [markdown]
# ✏️  **Answer 7 b**:
# > 1. While if we have a list within a tuple/list then conversion to array is deprecated.
# > 2. If we have multiple data types like integer and string in a list/tuple then upon conversion to the array we lose their data type.
# ***

# %% [markdown]
# ✍🏼 **Problem 8**: A classic dataset you should be aware of is the "mpg" dataset, which stands for "miles per gallon". In a code cell below, input the mpg dataset, show a portion of the data, print statistics for each column and make a Seaborn pairplot using "origin" as the hue.

# %% [markdown]
# ✏️  **Answer 8**:

# %%
# Loading of data and portion visualization
import seaborn as sns
df_mpg = sns.load_dataset("mpg")
df_mpg.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
# Statistics for each column
df_mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
# Pairplot for bivariate analysis
sns.pairplot(df_mpg, hue="origin")

# %% [markdown]
# ***
# ✍🏼 **Problem 9**: Open a markdown cell below and discuss what you learn from the mpg dataset. Vary the pairplot to explore the data in different ways. Do you learn anything from the basic IDA process? Does the EDA process provide additional information? At the end of your general discussion, be sure to include:
# * What do you get from the data? That is, what did you learn that you did not already know?
# * Even if the data itself is not that interesting to your boss, what uses might this dataset have as practice for doing data science?

# %% [markdown]
# ✏️  **Answer 9**:
# > MPG data set is one of the best datasets to start exploring. Taking origin as a classifier, we get the following insights:
# > - Cars in the USA overall had lower mpg and acceleration, while higher horsepower, weight, displacement and number of cylinders as compared to cars in Europe and Japan
# > - The graphs are a little skewed but close to a normal distribution, which signifies a good dataset.

# %%
# Pairplot for bivariate analysis
sns.pairplot(df_mpg, hue="model_year")

# %% [markdown]
# ✏️  **Answer 9**:
# > Taking the model year as a classifier, we get the following insights:
# > - With time, mpg and acceleration increased while displacement, horsepower, weight, and number of cylinders decreased. Signifying overall improvement in technology.
# > - The graphs are a little skewed but close to a normal distribution, which signifies a good dataset.

# %%
# Pairplot for bivariate analysis
sns.pairplot(df_mpg, hue="cylinders")

# %% [markdown]
# ✏️  **Answer 9**:
# > Taking Cylinders as a classifier, we get the following insights:
# > - As the number of cylinders decreased, the overall performance of the car in terms of mpg and acceleration increased.
# > - We also see a direct relation between the number of cylinders to displacement, horsepower, and weight.
# > - The graphs are a little skewed but close to a normal distribution, which signifies a good dataset.

# %% [markdown]
# ✏️  **Answer 9**:
# > - The IDA process gives us an idea about how data is structured within the dataset. It also helps us analyze hidden trends as one tends to explore every attribute in IDA. There is no predefined problem statement and hence it provides the liberty to explore new trends. IDA is also helpful in analyzing the type of distribution of an attribute and to detect outliers.
# > - The EDA process is more statistical, we analyze the mean, median, mode, and deviation of a dataset. We also check for missing values and try to populate them if required depending upon the attribute. So EDA provides more theoretical and detailed information about the features in the dataset.
# > - The data was quite interesting to work on. Just by looking at the pairplot, I was able to categorize different types of attributes like discrete, continuous, nominal, or cardinal. Clusters within attributes were visual in the plot.
# > - MPG dataset shows the real development trend in the auto sector and provides insights which go along with common science. It is decent data for analysis in the realm of data science, especially for those who are new to this field or have some knowledge.
# ***

# %% [markdown]
# ✍🏼 **Problem 10**: Perhaps the most popular dataset of all time is the "iris" dataset. This is a dataset you should know in great detail, as it appears everywhere. Repeat the previosu problem, but now for the "iris" dataset.

# %% [markdown]
# ✏️  **Answer 10**:

# %%
# Loading of data and portion visualization
df_iris = sns.load_dataset("iris")
df_iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Statistics for each column
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Pairplot for bivariate analysis
sns.pairplot(df_iris, hue="species")

# %% [markdown]
# ✏️  **Answer 10**:
# > Taking Species as a classifier, we get the following insights:
# > - The species can be easily classified using any two of the attributes, for example, sepal_width and petal_width clearly form clusters in the dataset.
# > - The graphs are a little skewed but very close to a normal distribution, which signifies a classic dataset.
# > - The iris dataset is well structured. Just by looking at the pairplot, I was able to visualize clusters in the data. Hence it is good for basic data science projects.
# ***

# %% [markdown]
# ✍🏼 **Problem 11**: This problem is the most difficult: be sure to give yourself plenty of time to work on it.
#
# If you get stuck, put your questions in the general channel on Slack so that other students can help and learn from you.
#
# There are two goals of this problem:
# 1. develop your ability to manage new Python libraries on your computer,
# 2. begin the first steps of building a DS-based web app for your midterm project.
#
# The reason this will be challenging is that:
# * you have some choices to make that will be unique to you,
# * your computer, its operatiing system and your library distributions are not necessarily like other students'.
#
# Here are the steps  to follow:
# 1. If you don't have one already, put a text editor on your computer. There are many to choose from: [Sublime](https://www.sublimetext.com/), [VSCode](https://code.visualstudio.com/), and so on. There are many times when using a Jupyter notebook, as amazing as they are, won't work. If you haven't used any of these editors, I recommend getting a few so that you can compare them. The choice is often very personal, which is why I am giving you the opportunity to explore and choose the best one for you.
# 2. Be sure that you can work at the command line. How this works differs greatly from computer to computer. For example, on a Mac you always have the [Terminal](https://en.wikipedia.org/wiki/Terminal_(macOS)). As with the editors, there are many choices, [like this](https://iterm2.com/).  If you are a windows user, you definitely want to [read this](https://www.makeuseof.com/tag/a-beginners-guide-to-the-windows-command-line/). Together, the editor and the command line will allow you to execute `.py` files, which can be really useful if you are using another computer (such as a cluster located somewhere else, such as MSU's HPCC facility).
# 3. Once those two steps are done, open the editor you chose and put this code in it, giving it any name you want, but ending with `.py`:
# ```
# import streamlit as st
# import seaborn as sns
# import pandas as pd
# from sklearn.datasets import load_wine
# import altair as alt
# wine_data = load_wine()
# labels = wine_data.feature_names
# targets = wine_data.target
# print(labels)
# df_form = pd.DataFrame(wine_data.data, columns = labels)
# df_form['targets'] = targets
# st.write("""
# # Italian Wine Dataset
# How are malic acid and alcohol correlated in Italian wines?
# """)
# alt_handle = alt.Chart(df_form).mark_circle(size=60).encode(x='alcohol', y='malic_acid',
# 	color='hue', tooltip=['ash', 'magnesium',
# 	'proanthocyanins']).interactive()
# st.altair_chart(alt_handle)
# ```
# Note that you will likely have to install some libraries on your computer.
# 4. At the command line, run your file using `name.py`, where `name` is whatever name you chose for your file in your editor. An interactive web app should appear in your browser. Don't worry about the details at this point, which we will cover later in the course: the goal for this HW is just to **get your computer setup properly** for deployable interactive DS apps.
# 5. In a markdown cell, put the answers to these questions:
# * which editor(s) did you choose, and why?
# * what did you decide to use for your command line? (e.g., are you on OSX and using the built-in `Terminal`?)
# * did you have any problems installing the libraries, such as `streamlit` and `altair`?
# * yes or no, did you get the interactive app working? if not, give details of your situation (i.e., your computer, what you tried, what you saw), so that we can fix the problems for next time.

# %% [markdown]
# ✏️  **Answer 11**:
# > - I choose visual studio code(vscode) due to following reasons:
# >   - It's the most widely used editor, hence community support is amazing. Community forums have answers to almost every problem.
# >   - It supports quite many languages, and I loved the magic python extension for writing python files.
# >   - It has a customized viewing option, where I can manage my panels as per my choice and also handle multiple workspaces at a time.
# >   - I tried atom, sublime text, markdown monster, and dillinger along with VScode but VScode had the best GUI as per my requirements.
# > - I decided to use windows command prompt because I have been using it for a while and hence I have a basic understanding about the application.
# > - I incurred a problem because my python was not synchronized with my workspace, which I managed to resolve using online resources. Apart from that no problem.
# > - Yes, my app is working, and please find a picture down below for reference.
#
# ![Interactive App](./HW1.PNG)
# ***

# %% [markdown]
# <center> Thank You! </center>

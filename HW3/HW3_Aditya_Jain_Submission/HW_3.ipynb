# %% [markdown]
# ### When you answer your questions, please use [emoji](https://getemoji.com/) and [good markdown](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html) so that it is easy for Vicente to find your work and grade it. Thanks!

# %% [markdown]
# Be sure to put your name here:
# * Aditya Jain

# %% [markdown]
# ____
#
# # HW #3
#
# ____

# %% [markdown]
# ____
# ## GitHub
#
# It important to have a public place to show your work, and GitHub (GH) is one of the standards you need to know for this. By the end of the semester you will have GH repos (repositories) for both of your projects. Among other goals, this will allow you to show off your work!
#
# I expect that the students in this class have very different experiences with GH, so this problem might be really short or really long.
#
# ✍🏻 (5pts) First, make a GH account for yourself [here](https://github.com/). Put your GH account information in a markdown cell. If you already have a GH repo, you do not need to create a new one; just put the name in the markdown cell. Or, create a new account for this class. I would like to collect the projects in one place so that we can all see them, even after the class is over.
#
# If you want to brush up on GH, or learn it from scratch, I recommend watching some YouTube videos. I recommend [this one](https://www.youtube.com/watch?v=x0EYpi38Yp4), or [this one](https://www.youtube.com/watch?v=DVRQoVRzMIY) and this pair: [first one](https://www.youtube.com/watch?v=USjZcfj8yxE) and [second one](https://www.youtube.com/watch?v=nhNq2kIvi9s).
#
# If you have any questions, please ask us! We are here to help!
#
# ✍🏻 (2 pts) Second, once you have your personal GH repo setup, practice by putting your web app from HW #2 there.
#
# Put a link to your web app here so that Vicente can check to see that it worked.

# %% [markdown]
# 📝 **Answer 1**:
# * My Github username - adiark and repo name - [CMSE_Project_App](https://github.com/adiark/CMSE_Project_App.git)
# * My web Application link - [application](https://adiark-cmse-project-app-app-5ds2la.streamlitapp.com/).

# %% [markdown]
# ____
# ## Project Practice
#
# This week you are going to practice for your midterm project. The midterm project is DS and the final project is machine learning (ML). What we want to explore in this problem is what we can do with DS.
#
# You will choose the topic of your project. This means:
# * you can use a dataset that you have from your job,
# * you can use a dataset that leads to a publication,
# * or, you can use a standard dataset if you don't have your own.
#
# The point is that this is flexible and can scale with each student. What I don't recommend is building your own dataset. While I would very much love to see that, there is a risk that it will take too long and possibly not lead to anything. (If you really want to do that, contact me!)
#
# Because the projects will be quite different, the instructions will be somewhat vague on purpose. But, here are the rules:
# 1. use most of the tools of EDA,
# 2. use visualization at a professional level (which we will cover soon),
# 3. be as quantitive as possible, using statistical tools,
# 4. have a question or goal in mind; or, if you explore a dataset, you should reach a new conclusion or observation about the dataset,
# 5. the final result will be a web app that others can access. (I will walk you through using `streamlit` with `GitHub` and `Heroku`, but talk to me if you want to use any of the many other options.)
#
# ✍🏻 (15 pts) Pick **three** datasets - your choice. You can find a lot of datasets [here](https://archive.ics.uci.edu/); search for topics that are of most interest to you. From these three datasets, write code to perform EDA on them and put that below. Below the EDA code cells for each dataset, open a markdown cell and write a paragraph that answers these questions:
# 1. why did you pick this dataset?
# 2. are there any interesting insights you gained from performing EDA on this dataset? (use all/most of the Seaborn tools we discussed this week)
# 3. are there any actionable insights you can get from this data? (For example, if you were a CEO and looking at the mpg dataset, what might you conclude?)
#
# Finally, open a new markdown and discuss which of these three datasets would make the best project dataset. Were some of the datasets disappointing? Was one much richer with possibilities? The reason you are asked to pick three is that some datasets is that you need to be able to assess which datasets are more or less interesting for your projects.
#
# [Here is an example you can follow that uses a wine dataset.](https://murillogroupmsu.com/wine/) It is also [at GH](https://gist.github.com/MurilloGroupMSU/678f61bbe225bdd166e8b946765d2931).

# %% [markdown]
# ---
# ✏️ **Dataset 1** - test_scores

# %%
# importing libraries 
import pandas as pd
import seaborn as sns

df_scores= pd.read_csv("test_scores.csv")
df_scores.head(10)
# Out:
#   school school_setting school_type classroom teaching_method  n_student  \
# 0  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 5  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 6  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 7  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 8  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 9  ANKYI          Urban  Non-public       6OL        Standard       20.0
#
#   student_id  gender             lunch  pretest  posttest
# 0      2FHT3  Female  Does not qualify     62.0      72.0
# ...

# %%
# basic datatype info
df_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school           2133 non-null   object
#  1   school_setting   2133 non-null   object
#  2   school_type      2133 non-null   object
#  3   classroom        2133 non-null   object
#  4   teaching_method  2133 non-null   object
#  5   n_student        2133 non-null   float64
#  6   student_id       2133 non-null   object
#  7   gender           2133 non-null   object
#  8   lunch            2133 non-null   object
#  9   pretest          2133 non-null   float64
#  10  posttest         2133 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 183.4+ KB

# %%
# basic Stats
df_scores= df_scores.dropna()
df_scores.describe()
# Out:
#          n_student      pretest     posttest
# count  2133.000000  2133.000000  2133.000000
# mean     22.796531    54.955931    67.102203
# std       4.228893    13.563101    13.986789
# min      14.000000    22.000000    32.000000
# 25%      20.000000    44.000000    56.000000
# 50%      22.000000    56.000000    68.000000
# 75%      27.000000    65.000000    77.000000
# max      31.000000    93.000000   100.000000

# %%
# visual way of looking at above data
sns.boxplot(df_scores)
# Out:
# <AxesSubplot:>

# %%
# Analysing correlation
sns.heatmap(df_scores.corr(),annot= True)
# Out:
# <AxesSubplot:>

# %%
# Analysing Distribution
df_scores.hist()
# Out:
# array([[<AxesSubplot:title={'center':'n_student'}>,
#         <AxesSubplot:title={'center':'pretest'}>],
#        [<AxesSubplot:title={'center':'posttest'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Analysis Categorical attributes
sns.catplot(df_scores,x= "teaching_method",y ="posttest",col= "school_setting", hue="school_type")

# %%
# Analysis Categorical attributes
sns.catplot(df_scores,x= "gender",y ="posttest",col= "school_setting", hue="school_type")

# %%
# Undetrstanding relation between number of student and test marks obtained
sns.lmplot(df_scores, x= "n_student",y="posttest", hue= "gender",col = 'school_setting',lowess=True)

# %%
# Correlation of marks with teaching method
sns.jointplot(df_scores, x= "posttest",y= "pretest", hue="teaching_method")

# %%
# Understanding distribution of data based on school setting
sns.pairplot(df_scores,hue="school_setting")

# %%
# Understanding distribution of data based on lunch
sns.pairplot(df_scores,hue="lunch")

# %% [markdown]
# ✏️ **Answer** :
# * 1 The dataset was enriched with multiple categorical attributes, along with a continuous dependent variable(test scores). The data seemed clean and attributes seemed appropriate in defining correlation with dependent variables
# * 2 There are multiple insights from the dataset :
#     * Students from non public school tends to score more on average
#     * Class with higher number of students tends to score less on average
#     * Standard teaching method is more beneficial for students then experimental method
#     * Suburban school tends to perform best in terms of marks with optimum number of students
# * 3 As a CEO i would try to implement strategies of suburban teaching environment in both rural and urban schools to get the optimum results

# %% [markdown]
# ✏️ **Dataset 2**: Diabetes_dataset__2019

# %%
# Importing Dataset
df_dia= pd.read_csv("Diabetes_dataset__2019.csv")
df_dia.head(10)
# Out:
#             Age Gender Family_Diabetes highBP      PhysicallyActive   BMI  \
# 0         50-59   Male              no    yes        one hr or more  39.0
# 1         50-59   Male              no    yes  less than half an hr  28.0
# 2         40-49   Male              no     no        one hr or more  24.0
# 3         50-59   Male              no     no        one hr or more  23.0
# 4         40-49   Male              no     no  less than half an hr  27.0
# 5         40-49   Male              no    yes                  none  21.0
# 6  less than 40   Male              no     no        one hr or more  24.0
# 7  less than 40   Male              no     no  less than half an hr  20.0
# 8         40-49   Male             yes     no        one hr or more  23.0
# 9  less than 40   Male              no     no  more than half an hr  20.0
#
#   Smoking Alcohol  Sleep  SoundSleep RegularMedicine      JunkFood     Stress  \
# ...

# %%
# Changing names and values in the fetched data
df_dia.rename(columns = {'Pregancies':'Pregnancies'}, inplace = True)
df_dia['Diabetic']=df_dia['Diabetic'].map({'yes':1,'no':0})
df_dia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               952 non-null    object
#  1   Gender            952 non-null    object
#  2   Family_Diabetes   952 non-null    object
#  3   highBP            952 non-null    object
#  4   PhysicallyActive  952 non-null    object
#  5   BMI               948 non-null    float64
#  6   Smoking           952 non-null    object
#  7   Alcohol           952 non-null    object
#  8   Sleep             952 non-null    int64
#  9   SoundSleep        952 non-null    int64
#  10  RegularMedicine   952 non-null    object
#  11  JunkFood          952 non-null    object
#  12  Stress            952 non-null    object
#  13  BPLevel           952 non-null    object
#  14  Pregnancies       910 non-null    float64
#  15  Pdiabetes         951 non-null    object
# ...

# %%
# cleaning data
df_dia= df_dia.dropna()
df_dia.describe()
# Out:
#               BMI       Sleep  SoundSleep  Pregnancies    Diabetic
# count  905.000000  905.000000  905.000000   905.000000  905.000000
# mean    25.520442    6.956906    5.546961     0.386740    0.290608
# std      5.276835    1.287843    1.870904     0.910023    0.454294
# min     15.000000    4.000000    0.000000     0.000000    0.000000
# 25%     22.000000    6.000000    4.000000     0.000000    0.000000
# 50%     24.000000    7.000000    6.000000     0.000000    0.000000
# 75%     28.000000    8.000000    7.000000     0.000000    1.000000
# max     45.000000   11.000000   11.000000     4.000000    1.000000

# %%
# Outliers Analysis
sns.boxplot(df_dia)
# Out:
# <AxesSubplot:>

# %%
# Analysing correlation
sns.heatmap(df_dia.corr(),annot= True)
# Out:
# <AxesSubplot:>

# %%
# histogram plot
df_dia.hist()
# Out:
# array([[<AxesSubplot:title={'center':'BMI'}>,
#         <AxesSubplot:title={'center':'Sleep'}>],
#        [<AxesSubplot:title={'center':'SoundSleep'}>,
#         <AxesSubplot:title={'center':'Pregnancies'}>],
#        [<AxesSubplot:title={'center':'Diabetic'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Analysis Categorical attributes
sns.catplot(df_dia.where(df_dia.Gender == "Female"),x= "Pregnancies",y ="BMI",col= "Age", hue="Diabetic"
            ,col_order= ["less than 40","40-49","50-59","60 or older"])

# %%
# Analysis Categorical attributes
sns.catplot(df_dia ,x= "BPLevel",y ="BMI",col= "Age", hue="Diabetic", kind= "box"
            ,col_order= ["less than 40","40-49","50-59","60 or older"],
            order= ["low", "normal", "high"])

# %%
# jointplot 
sns.jointplot(df_dia, x= "BMI",y= "Sleep", hue="Diabetic")

# %%
# Undetrstanding relation between number of student and test marks obtained
sns.pairplot(df_dia)

# %% [markdown]
# ✏️ **Answer** :
# * 1 The dataset comprised of both continuous and categorical attributes with a binary dependent variable. It has higher number of attributes but low number of continuous variable.
# * 2 Insights from the dataset are :
#     * Individuals in older ages with high BP have a higher chances of getting diabetic
#     * Individuals with low BMI have higher chances of getting diabetic in older ages
# * 3 As the manager of my healt, i would start maintain my BMI, and take care of my blood pressure.

# %% [markdown]
# ✏️ **Dataset 3**: Bank Marketing Dataset

# %%
# reading dataset
df_bank = pd.read_csv("bank-additional.csv", sep= ";")
df_bank.head(10)
# Out:
#    age           job   marital            education  default  housing  \
# 0   30   blue-collar   married             basic.9y       no      yes
# 1   39      services    single          high.school       no       no
# 2   25      services   married          high.school       no      yes
# 3   38      services   married             basic.9y       no  unknown
# 4   47        admin.   married    university.degree       no      yes
# 5   32      services    single    university.degree       no       no
# 6   32        admin.    single    university.degree       no      yes
# 7   41  entrepreneur   married    university.degree  unknown      yes
# 8   31      services  divorced  professional.course       no       no
# 9   35   blue-collar   married             basic.9y  unknown       no
#
#       loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 0       no   cellular   may         fri  ...         2    999         0
# ...

# %%
# checking datatype
df_bank['y']= df_bank['y'].map({'yes':1,'no':0})
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
# baisc Stats
df_bank= df_bank.dropna()
df_bank.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed  \
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
# outliers detection
sns.boxplot(df_bank)
# Out:
# <AxesSubplot:>

# %%
# correlation plot
cm = sns.light_palette("green", as_cmap=True)

df_bank.corr().style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_23d92_row0_col0, #T_23d92_row1_col1, #T_23d92_row2_col2, #T_23d92_row3_col3, #T_23d92_row4_col4, #T_23d92_row5_col5, #T_23d92_row6_col6, #T_23d92_row7_col7, #T_23d92_row8_col8, #T_23d92_row9_col9, #T_23d92_row10_col10 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_23d92_row0_col1 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_23d92_row0_col2 {
#   background-color: #daebda;
#   color: #000000;
# }
# #T_23d92_row0_col3, #T_23d92_row1_col3, #T_23d92_row7_col4, #T_23d92_row8_col7 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_23d92_row0_col4 {
#   background-color: #8dc58d;
#   color: #000000;
# }
# #T_23d92_row0_col5 {
#   background-color: #a9d3a9;
#   color: #000000;
# }
# #T_23d92_row0_col6 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_23d92_row0_col7 {
#   background-color: #c2dfc2;
#   color: #000000;
# }
# #T_23d92_row0_col8, #T_23d92_row0_col10 {
#   background-color: #a4d0a4;
# ...

# %%
# histogram plot to understand distribution
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,6)); ax = fig.gca()
df_bank.hist(bins=30, ax=ax)
plt.tight_layout()
# Out:
# C:\Users\Adi\AppData\Local\Temp\ipykernel_27260\921825050.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df_bank.hist(bins=30, ax=ax)

# %%
# Categorical attributes
sns.catplot(df_bank, x= "marital",y = "age", hue= "y")

# %%
# jointplot of Age and duration
sns.jointplot(df_bank, x= "age",y= "duration", hue= "y")

# %%
# regression plot between age and campaign
sns.lmplot(df_bank, x= "age",y="campaign", hue= "y",col = 'marital',lowess=True)

# %%
# regression plot between age and duration
sns.lmplot(df_bank, x= "age",y="duration", hue= "y",col = 'marital',lowess=True)

# %% [markdown]
# ✏️ **Answer** :
# * 1 Along with the client data, the dataset had attributes from social economic context which I presumed will be a good way to understand correlation between attributes of different domains.
# * 2 The insights from the dataset are:
#     * The data is filled with outlier values and mean and st deviation of duration and campaign are very close, meaning noisy data.
#     * No normal distribution among attributes
#     * Most of the people who subscribed back attended less than 5 campaigns
# * 3 As a CEO I would try to gather more data points for the problem, more continuous/ categorical variables that are logically correlated with the dependent variable. Also as data suggest conversion rate is max within 5 campaigns, so to save money i would run marketing schems limiting to 5 campaigns per person.

# %% [markdown]
# ✏️ The test Score data set would be the most interesting one as attributes in that dataset were more logically connected. Due to various connected categorical variables deriving conclusions was easy, while in other dataset it was hard to understand relation between variables.
#
# ❗ I thought that more data would provide me more information, but as witnessed, data should be more powerfull and meaningfull rather than abundant in nature.

# %% [markdown]
# ____
# ## Pandas Practice
#
# ✍🏻  (10pts) From the standard penguins dataset, answer this question: what percentage of female penguins from Dream have a body mass greater than $4000$ grams? (Use only Pandas attributes and methods. Show your code as well as your answer.)

# %% [markdown]
# 📝 **Answer**:

# %%
# Loading libraries and dataset and performing analysis
from itertools import count

df_peng = sns.load_dataset("Penguins")
f_dream_data = df_peng.where(df_peng['sex'] == "FEMALE").where(df_peng['island'] == "Dream").dropna()
f_perc = len(f_dream_data.where(f_dream_data['body_mass_g'] > 4000).dropna())/len(f_dream_data)
print("Percentage of female penguins from dream with body mass greater than 4000 grams is",round(f_perc*100,2),"%")
# Out:
# Percentage of female penguins from dream with body mass greater than 4000 grams is 1.64 %

# %% [markdown]
# ____
# ## Heroku Account
#
# ✍🏻 (5 pts) Sign up for a student Heroku account [here](https://www.heroku.com/).
#
#
# 📝 **Heroku email id - jainadi5@msu.edu**

# %% [markdown]
# ____
# ## PEP-8
#
# ✍🏻 (5 pts) Which of these follows the [PEP-8 standard](https://peps.python.org/pep-0008/)?
#
# * `if x == 4 : print(x , y) ; x , y = y , x`
# * `if x == 4: print(x, y); x, y = y, x`
# * neither of these
#
# 📝 **Answer** : B - `if x == 4: print(x, y); x, y = y, x`

# %% [markdown]
# ____
# ## EDA: Seaborn and Correlations
#
# ✍🏻  (10pts) Read in the mpg dataset and perform EDA on it. Specifically:
# * get the basic statistics from the df,
# * make a `displot` of horsepower versus mpg, including a rug plot and with a kde,
# * make a Seaborn `heatmap` of the correlations using Pandas' `.corr`, with annotations and your choice of colormap,
# * make a `regplot` ([or, `lmplot`](https://seaborn.pydata.org/tutorial/regression.html)) of horsepower versus mpg using the lowess smoother; choose good colors,
# * design a `FacetGrid` of your choice.
#
# After each plot, open a markdown cell and give one sentence of what the plot tells you. That is, as a data scientist, what did this form of EDA reveal about the data? (If it didn't reveal anything to you, that is also an important possible answer.)

# %% [markdown]
# 📝 **Answer**:

# %%
# Loading and describing mpg dataset
df_mpg = sns.load_dataset("mpg")
df_mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
# displot of horsepower vs mpg
sns.set_style("darkgrid")
sns.displot(data = df_mpg, x= "horsepower", y= "mpg", kind= "kde", rug= True).set(title = "Displot of horsepower vs mpg")

# %% [markdown]
# ✏️ The chart tells us about the relation between horsepower and mpg, as visible less horsepower is proportionate to higher mpg

# %%
# heatmap of correlation values between attributes
sns.heatmap(df_mpg.corr(), annot= True,  cmap = "Blues").set(title = "Heatmap Correlation")
# Out:
# [Text(0.5, 1.0, 'Heatmap Correlation')]

# %% [markdown]
# ✏️ The heatmap tell us about how strongly attributes within dataset are correlated to eachother, help us filter dataset.

# %%
# regplot / lmplot of horsepower vs mpg using lowess smoother
sns.regplot(data= df_mpg, x= "horsepower", y= "mpg", lowess= True, color= "green").set(title= "Regression plot of horsepower vs mpg")
# Out:
# [Text(0.5, 1.0, 'Regression plot of horsepower vs mpg')]

# %% [markdown]
# ✏️ The line in above chart tells us an estimate relation between horsepower and mpg among the sample set, this type of regression is generally used in predicting continuous variables.

# %%
# Facetgrid 
fig = sns.FacetGrid(data= df_mpg, col= "origin", hue= "cylinders")
fig.map(sns.scatterplot, "weight", "acceleration", alpha= 0.5)
fig.add_legend()

# %% [markdown]
# ✏️ As clearly visible, we can see clusters of different colors revealing patterns, like four cylinders are optimum for a cars performance.

# %%
# Facetgrid 
fig = sns.FacetGrid(data= df_mpg, col= "origin", hue= "cylinders")
fig.map(sns.scatterplot, "mpg", "weight", alpha= 0.5)
fig.add_legend()

# %% [markdown]
# ✏️ As visible, more weight means less mpg.

# %% [markdown]
# <center> Thank You! <center>
